# %% [markdown]
# ## Osnove jezika

# %% [markdown]
# ### Primjer

# %%
SUFFIXES = { 1000: ['KB', 'MB', 'GB', 'TB', 'PB', 'EB', 'ZB', 'YB'], 
	    1024: ['KiB', 'MiB', 'GiB', 'TiB', 'PiB', 'EiB', 'ZiB', 'YiB']} 

def approximate_size(size, kb_is_1024_bytes = True): 
	'''Convert a file size to human-readable form. 
	   Description…
	''' 
	
	if size < 0: 
		raise ValueError('number must be non-negative') 

	multiple = 1024 if kb_is_1024_bytes else 1000 

	for suffix in SUFFIXES[multiple]: 
		size /= multiple 
		if size < multiple: 
			return 'Size is {0} {1}!'.format(size, suffix) 

	raise ValueError('number too large') 

if __name__ == '__main__': 
	print(approximate_size(1000000000000, False)) 
	print(approximate_size(1000000000000))
	print(approximate_size(-1000000000000))
# Out:
# Size is 1.0 TB!
# Size is 931.3225746154785 GiB!
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-5781bbdeaf0c> in <module>
#      22         print(approximate_size(1000000000000, False))
#      23         print(approximate_size(1000000000000))
# ---> 24         print(approximate_size(-1000000000000))
#
# <ipython-input-21-5781bbdeaf0c> in approximate_size(size, kb_is_1024_bytes)
#       8
#       9         if size < 0:
# ---> 10                 raise ValueError('number must be non-negative')
#      11
#      12         multiple = 1024 if kb_is_1024_bytes else 1000
#
# ValueError: number must be non-negative

# %%
ocjena = {'Iva': 5, 'Marko': 4}

# %%
ocjena['Marko'] = 3
ocjena['Ana'] = 2

# %%
ocjena['Iva']
# Out:
# 5

# %%
ocjena
# Out:
# {'Iva': 5, 'Marko': 3, 'Ana': 2}

# %%
ocjena['1B'] = {'Ivo': 4, 'Pero': 3}

# %%
ocjena
# Out:
# {'Iva': 5, 'Marko': 3, 'Ana': 2, '1B': {'Ivo': 4, 'Pero': 3}}

# %%
ocjena['1B']['Pero']
# Out:
# 3

# %%
print(approximate_size(10000000000000000000000000000000000000))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-d6f4e1a176c1> in <module>
# ----> 1 print(approximate_size(10000000000000000000000000000000000000))
#
# <ipython-input-3-80cccb059c47> in approximate_size(size, kb_is_1024_bytes)
#      17                         return 'Size is {0} {1}!'.format(size, suffix)
#      18
# ---> 19         raise ValueError('number too large')
#      20
#      21 if __name__ == '__main__':
#
# ValueError: number too large

# %%
a = 3
  b = 4
# Out:
#   File "<ipython-input-22-f729ffbad5e1>", line 2
#     b = 4
#     ^
# IndentationError: unexpected indent

# %%
raise ValueError('neka poruka')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-7852781b49bc> in <module>
# ----> 1 raise ValueError('neka poruka')
#
# ValueError: neka poruka

# %%
for x in [10, 20, 30]:
    print(x)
# Out:
# 10
# 20
# 30

# %% [markdown]
# ### Tipovi podataka

# %%
var = 10

# %%
type(var)
# Out:
# int

# %%
var = 'str'
type(var)
# Out:
# str

# %%
mapa = {1:2, 2:3}
isinstance(mapa, dict)
# Out:
# True

# %%
isinstance(mapa, int)
# Out:
# False

# %%
x = []
type(x)
# Out:
# list

# %%
if not x:
    print('do something')
    
bool('')
# Out:
# do something
# False

# %%
1000000000000000000000000000000000000000000000000000000000001 + 28888888888888888888888888888888888888888888

# %%
2.3 + 2

# %%
2/3

# %%
2//3

# %%
int(2.3)

# %%
float(2)

# %%
2 ** 2300000
# Out:
# ...

# %%
import fractions

# %%
a = fractions.Fraction(2, 3)
b = fractions.Fraction(2, 5)
a + b
# Out:
# Fraction(16, 15)

# %%
a + 2.5
# Out:
# 3.1666666666666665

# %%
a = complex(1, 3)

# %%
b = complex(2, 5)
a * b
# Out:
# (-13+11j)

# %% [markdown]
# ### Liste

# %%
lista = [1, '2', 3.0, '4', 5]

# %%
lista[2]
# Out:
# 3.0

# %%
lista[0]

# %%
lista[-5]

# %%
lista[4]

# %%
lista[-1]

# %%
lista[1:3]

# %%
lista[:3]

# %%
lista[-3:]

# %%
lista[:]

# %%
lista1 = [1, 2, 3]
lista2 = [4, 5, 6]
nova_lista = lista1 + lista2
nova_lista

# %%
nova_lista.append('end')
nova_lista

# %%
lista3 = [7, 8, 9]
nova_lista.extend(lista3)
nova_lista

# %%
nova_lista.insert(-2, 'almostend')
nova_lista

# %%
len(nova_lista)

# %%
nova_lista.count(1)

# %%
nova_lista.count(10)

# %%
103 in nova_lista

# %%
nova_lista.index(3)

# %%
nova_lista.index(103)

# %%
x = 'end'
if x in nova_lista:
    print(nova_lista.index(x))

# %%
nova_lista

# %%
del nova_lista[-3]
nova_lista

# %%
nova_lista.remove(1)
nova_lista

# %%
nova_lista.remove(102)

# %%
x = 102
if x in nova_lista:
    nova_lista.remove(x)
nova_lista

# %%
# Zadatak 12.

def first_n(n=3):
    i = 0
    lista = []
    while i < n:
        lista.append(i)
        i += 1
    return lista


def rem(x, l):
    if x in l:
        index = l.index(x)
        del l[index]
    return l


l = first_n(10)
rem('ne postoji', l)

# %%
l1 = [1, 2, 3]
l2 = l1
l2

l2[0] = -10
l1

# %%
l1 = [1, 2, 3]
l2 = l1[:]

l2[0] = -10
l2

# %%
l1 = [[1, 2, 3],[4, 5, 6]]
l2 = l1[:]
l2[0][0] = -10
l1

# %%
import copy
l1 = [[1, 2, 3],[4, 5, 6]]
l2 = copy.deepcopy(l1)

l2[0][0] = -10
l1

# %% [markdown]
# ### N-torke

# %%
n_torka = (1, 2, 3, '4')
type(n_torka)

# %%
n_torka[0]

# %%
n_torka.index(10)

# %%
n_torka.count(2)

# %%
len(n_torka)

# %%
1 in n_torka

# %%
lista = list(n_torka)
lista

# %%
novi_tuple = tuple(lista)
novi_tuple

# %%
x, y, z = 1, 5, 7
t = 1, 5, 7

# %%
def vrati_dan_i_mjesec(datum):
    #...
    return d, m

# %%
l = first_n(10)
def head_tail(l, n=3):
    return l[:n], l[-n:]

head_tail(l, 3)

# %% [markdown]
# ### Skupovi

# %%
s = {1, 2, 3, 3}
s

# %%
s = {1, 2.3, 'pero', (1, 2, 3)}
s

# %%
s = {[1, 2, 3], 3}

# %%
type(s)

# %%
s = {1, 2.3, 'pero', (1, 2, 3)}

# %%
s.add(10)
s

# %%
s.update(['1', '2', 'ante'])
s

# %%
s.discard('pero')
s

# %%
l = [1, 2, 3, 1, 2, 3, 4, 5, 6, 1]
l = list(set(l))
l

# %%
a = {1, 2, 3}
b = {3, 4, 5}

def jaccard(a, b):
    return len(a & b)/len(a | b)

jaccard(a, b)

# %% [markdown]
# ### Mape

# %%
mapa = {1 : 'prvi', 2 : 'drugi', 3 : 'treci'}
type(mapa)

# %%
mapa[1]

# %%
mapa[4] = 'cetiri'
mapa

# %%
mapa[4] = [1, 2, 3, 4]
mapa

# %%
mapa.get(4)

# %%
mapa.get('k', '')

# %%
if not mapa.get('k', ''):
    print('do_something')

# %%
len(mapa)

# %%
1 in mapa

# %%
10 in mapa

# %%
mapa

# %%
list(mapa.keys())

# %%
list(mapa.values())

# %%
list(mapa.items())
